# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 1.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 10.5 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Image Process Weeek - 3

# %%
from matplotlib.colors import ListedColormap

# %%
import numpy as np

# %%
print(np.linspace(1,10,5))
#linesoace(start,stop, step)
# Out:
# [ 1.    3.25  5.5   7.75 10.  ]

# %%
gr = np.linspace(0,1,100)
gr_image = np.outer(gr,gr) #matris haline getirdik
#outer

# %% [markdown]
# image neden matris
# neden 0-1 atalığında

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# what is diffarende between imshow and show function
#
# imshow is used to  display data as an image, show is used is used to display all figures

# %%
cmap=ListedColormap(['r','g','b'])
plt.imshow(gr_image,cmap=cmap)
plt.colorbar()
plt.show()

# %%
#şöyle gray hale de geirebiliriz
plt.imshow(gr_image, cmap="gray")
plt.colorbar()
plt.show()

# %%
print(gr_image[99][99])
# Out:
# 1.0

# %%
import cv2

# %%
path_img = "/Users/gokcesoylu/lionpool.jpeg"
image = cv2.imread(path_img)

# %% [markdown]
# imshow ?
# sol üst 0,0 olur

# %% [markdown]
# burada dokızuncu satırxda ahata alıyroum

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))
plt.show()

# %%
img = cv2.imread(path_img)
img2 = img[:,:,::-1]
plt.imshow(img2)

# %%
img = cv2.imread(path_img)
plt.imshow(img)

# %%
img = cv2.imread(path_img,1)
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))

# %%
w,h,c = image.shape
print(w,h,c)
# Out:
# 958 1280 3

# %%
print("B = ", image[0][0][0])
print("G = ", image[0][0][1])
print("R = ", image[0][0][2])
# Out:
# B =  93
# G =  26
# R =  1
