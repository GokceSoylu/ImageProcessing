# %% [markdown]
# # Convert Image to Gray

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ## read image

# %%
img_path = "/Users/gokcesoylu/lionpool.jpeg"
the_image = cv2.imread(img_path)

# %% [markdown]
# ## convert grayscale

# %%
gray_image = cv2.cvtColor(the_image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ## display image

# %%
plt.imshow(gray_image,cmap='gray')
plt.colorbar()
plt.show()

# %% [markdown]
# garyscale dçönüşümü olmadan direkt plt.imshow ile cmap gray diyerek resmi görüntülemeye çalışırsan
#
# renkli görüntüyü gri tonlarında göstermeey çallışır ve haliliyle renkte bozulmalar olur.
#
# örneği, aşıda

# %%
plt.imshow(the_image,cmap='gray')
plt.colorbar()
plt.show()
